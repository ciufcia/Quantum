# %% [markdown]
# 1. Implement Deutsch-Jozsa algorithm which checks of the following function is constant or balanced: \
# $ 000 \rightarrow 0$ \
# $ 001 \rightarrow 0$ \
# $ 010 \rightarrow 0$ \
# $ 011 \rightarrow 0$ \
# $ 100 \rightarrow 1$ \
# $ 101 \rightarrow 1$ \
# $ 110 \rightarrow 1$ \
# $ 111 \rightarrow 1$
#
# 1. Implement Deutsch-Jozsa algorithm where the number of bits on input to the function we analyze is a parameter and can be modified. Also oracle should be implemented in separate function.
#
# 1. Implement Grover algorithm searching for state $\ket{1011}$ among 16 possible 4-gubit basis states. Run it on simulator.
#
# 1. Transpile circuit from Exercise 1 using various optimization methods available in Qiskit. Run the transpilation 100 times in a loop and create barchart with number of 2-qubit gates distribution.
#
# 1. Calculate expectation value of the following Hamiltonian in any state:
# `hamiltonian = SparsePauliOp.from_list([("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)])` using real quantum computer
#
# 1. Run GHZ state and $H^3$ circuits (so set of 2 circuits) on:
#     * StatevectorSampler using single job - locally
#     * Sampler primitive using single job - on real backend
#
# 1. Read:
#     * https://docs.quantum.ibm.com/guides/get-started-with-primitives
#     * https://docs.quantum.ibm.com/guides/primitive-input-output
#     * https://docs.quantum.ibm.com/guides/primitives-examples
#     * https://docs.quantum.ibm.com/guides/runtime-options-overview
#     * https://docs.quantum.ibm.com/guides/specify-runtime-options
#     * https://docs.quantum.ibm.com/guides/configure-error-mitigation
#
# 1. Calculate expectation value of any operator for parametrized circuit and draw chart showing them for multiple values of the parameter.
